# %%
# !pip install mnist
# Out:
# Requirement already satisfied: mnist in /usr/local/lib/python3.7/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mnist) (1.21.6)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
#import mkl

#mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

#def softmax(batch):
#    raise Exception('Softmax activation function is not implemented!')

# Skopiowane z SiNiUG_lab6.ipynb
def softmax(batch):
    max_value = np.max(batch, axis=1, keepdims=True)
    z = batch - max_value
    numerator = np.exp(z)
    denominator = np.sum(numerator, axis=1, keepdims=True)
    softmax = numerator/denominator
    return softmax

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    if stochastic:
        #return np.maximum(0, batch)
        return np.maximum(0, batch + np.random.normal(scale=np.sqrt(sigmoid(batch)), size=batch.shape))
        
    else:
        #return np.maximum(0, batch + np.random.normal(scale=np.std(batch), size=batch.shape))
        return np.maximum(0, batch)


def relu_derivative(batch):
    #temporary = batch.copy()
    return np.where(batch > 0, 1, 0)

# %%
def limit_weights(weights, limit):
    norms = np.linalg.norm(weights, axis=0) # Liczenie norm kolumnami
    result = weights * np.where(norms > limit, limit / norms, 1)
    
    weights = result
    return result

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
# Skopiowane z SiNiUG_lab6.ipynb
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        #raise Exception('Compute layer activations here!')
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            #raise Exception('Remember about the derivatives of the activation function!')
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
# Skopiowane z SiNiUG_lab6.ipynb
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    #error('Error backpropagation is unimplemented')
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            #raise Exception("Calculate the deltas in 'prev_layer'")
            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
        else:
            visible = batch
        
        #raise Exception("Update the momentum matrix with gradient from error backpropagation")
        gradient = (visible.T @ layer.deltas) / observations_count
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        
        layer.W += layer.M

### DODATEK Z SiNiUG_lab8.ipynb !!! To przez to wcześniej nie działało!!!
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
# Skopiowane z SiNiUG_lab6.ipynb
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        #raise Exception("Delta in the sofmax layer is unimplemented!")
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
# Skopiowane z SiNiUG_lab7.ipynb
def initialize_mlp(mlp, dbn):
  # Dostaje dbna i mlp - sekwencja warst
  # Zainicjalizuj mlp za pomocą wag dbn'a - ostatnia część poniedziałkowego wykładu
  # Wagi w mlp w liście Layer , skopiuj wagi z dbna niektóre elementy usuwając
  # Uwaga w numpy: Layer.podstaw dbn.w tylko PODSTAWIA REFERENCJE!!! - zadbaj o kopię
  for layer, rbn in zip(mlp, dbn):
    layer.W = np.copy(rbn.W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.90s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.87s, accuracy: 45.92
# Epoch 3:	########################################	elapsed: 0.85s, accuracy: 65.33
# Epoch 4:	########################################	elapsed: 0.85s, accuracy: 75.49
# Epoch 5:	########################################	elapsed: 0.85s, accuracy: 80.81
# Epoch 6:	########################################	elapsed: 0.88s, accuracy: 89.88
# Epoch 7:	########################################	elapsed: 0.90s, accuracy: 92.08
# Epoch 8:	########################################	elapsed: 0.90s, accuracy: 93.66
# Epoch 9:	########################################	elapsed: 0.88s, accuracy: 93.59
# Epoch 10:	########################################	elapsed: 0.86s, accuracy: 94.55
# Epoch 11:	########################################	elapsed: 0.92s, accuracy: 93.77
# Epoch 12:	########################################	elapsed: 0.88s, accuracy: 95.25
# Epoch 13:	########################################	elapsed: 0.88s, accuracy: 95.58
# Epoch 14:	########################################	elapsed: 0.86s, accuracy: 95.48
# Epoch 15:	########################################	elapsed: 0.88s, accuracy: 94.59
# Epoch 16:	########################################	elapsed: 0.87s, accuracy: 94.96
# Epoch 17:	########################################	elapsed: 0.86s, accuracy: 95.42
# Epoch 18:	########################################	elapsed: 0.86s, accuracy: 95.97
# Epoch 19:	########################################	elapsed: 0.86s, accuracy: 95.95
# Epoch 20:	########################################	elapsed: 0.89s, accuracy: 96.56
# Epoch 21:	########################################	elapsed: 0.92s, accuracy: 96.63
# Epoch 22:	########################################	elapsed: 0.86s, accuracy: 96.74
# Epoch 23:	########################################	elapsed: 0.86s, accuracy: 96.72
# Epoch 24:	########################################	elapsed: 0.89s, accuracy: 96.73
# Epoch 25:	########################################	elapsed: 0.88s, accuracy: 96.76
# Epoch 26:	########################################	elapsed: 0.88s, accuracy: 96.76
# Epoch 27:	########################################	elapsed: 0.88s, accuracy: 96.77
# Epoch 28:	########################################	elapsed: 0.88s, accuracy: 96.77
# Epoch 29:	########################################	elapsed: 0.89s, accuracy: 96.76
# Epoch 30:	########################################	elapsed: 0.87s, accuracy: 96.75
# Epoch 31:	########################################	elapsed: 0.88s, accuracy: 96.75
# Epoch 32:	########################################	elapsed: 0.91s, accuracy: 96.74
# Epoch 33:	########################################	elapsed: 0.90s, accuracy: 96.73
# Epoch 34:	########################################	elapsed: 0.87s, accuracy: 96.74
# Epoch 35:	########################################	elapsed: 0.96s, accuracy: 96.75
# Epoch 36:	########################################	elapsed: 0.95s, accuracy: 96.75
# Epoch 37:	########################################	elapsed: 0.88s, accuracy: 96.76
# Epoch 38:	########################################	elapsed: 0.85s, accuracy: 96.77
# Epoch 39:	########################################	elapsed: 0.88s, accuracy: 96.76
# Epoch 40:	########################################	elapsed: 0.87s, accuracy: 96.76
# Epoch 41:	########################################	elapsed: 0.88s, accuracy: 96.76
# Epoch 42:	########################################	elapsed: 0.88s, accuracy: 96.76
# Epoch 43:	########################################	elapsed: 0.89s, accuracy: 96.76
# Epoch 44:	########################################	elapsed: 0.87s, accuracy: 96.77
# Epoch 45:	########################################	elapsed: 0.89s, accuracy: 96.77
# Epoch 46:	########################################	elapsed: 0.87s, accuracy: 96.78
# Epoch 47:	########################################	elapsed: 0.87s, accuracy: 96.78
# Epoch 48:	########################################	elapsed: 0.87s, accuracy: 96.77
# Epoch 49:	########################################	elapsed: 0.88s, accuracy: 96.77
# Epoch 50:	########################################	elapsed: 0.88s, accuracy: 96.77
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.73
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.22s, reconstruction error: 75.30
# Epoch 2:	########################################	elapsed: 1.09s, reconstruction error: 55.33
# Epoch 3:	########################################	elapsed: 1.09s, reconstruction error: 42.57
# Epoch 4:	########################################	elapsed: 1.10s, reconstruction error: 36.36
# Epoch 5:	########################################	elapsed: 1.08s, reconstruction error: 32.48
# Epoch 6:	########################################	elapsed: 1.37s, reconstruction error: 24.90
# Epoch 7:	########################################	elapsed: 1.56s, reconstruction error: 21.02
# Epoch 8:	########################################	elapsed: 1.10s, reconstruction error: 18.53
# Epoch 9:	########################################	elapsed: 1.11s, reconstruction error: 16.77
# Epoch 10:	########################################	elapsed: 1.15s, reconstruction error: 15.58
# Epoch 11:	########################################	elapsed: 1.10s, reconstruction error: 14.67
# Epoch 12:	########################################	elapsed: 1.11s, reconstruction error: 13.67
# Epoch 13:	########################################	elapsed: 1.10s, reconstruction error: 13.06
# Epoch 14:	########################################	elapsed: 1.15s, reconstruction error: 12.32
# Epoch 15:	########################################	elapsed: 1.10s, reconstruction error: 11.90
# Epoch 16:	########################################	elapsed: 1.13s, reconstruction error: 11.37
# Epoch 17:	########################################	elapsed: 1.14s, reconstruction error: 10.90
# Epoch 18:	########################################	elapsed: 1.13s, reconstruction error: 10.60
# Epoch 19:	########################################	elapsed: 1.16s, reconstruction error: 10.35
# Epoch 20:	########################################	elapsed: 1.13s, reconstruction error: 10.04
# Epoch 21:	########################################	elapsed: 1.38s, reconstruction error: 9.76
# Epoch 22:	########################################	elapsed: 1.90s, reconstruction error: 9.64
# Epoch 23:	########################################	elapsed: 2.72s, reconstruction error: 9.42
# Epoch 24:	########################################	elapsed: 1.66s, reconstruction error: 9.22
# Epoch 25:	########################################	elapsed: 1.52s, reconstruction error: 9.10
# Epoch 26:	########################################	elapsed: 2.07s, reconstruction error: 8.92
# Epoch 27:	########################################	elapsed: 1.38s, reconstruction error: 8.94
# Epoch 28:	########################################	elapsed: 1.81s, reconstruction error: 8.91
# Epoch 29:	########################################	elapsed: 1.62s, reconstruction error: 8.78
# Epoch 30:	########################################	elapsed: 1.49s, reconstruction error: 8.74
# Epoch 31:	########################################	elapsed: 1.39s, reconstruction error: 8.74
# Epoch 32:	########################################	elapsed: 2.10s, reconstruction error: 8.54
# Epoch 33:	########################################	elapsed: 1.16s, reconstruction error: 8.57
# Epoch 34:	########################################	elapsed: 1.16s, reconstruction error: 8.48
# Epoch 35:	########################################	elapsed: 1.14s, reconstruction error: 8.43
# Epoch 36:	########################################	elapsed: 1.14s, reconstruction error: 8.35
# Epoch 37:	########################################	elapsed: 1.15s, reconstruction error: 8.26
# Epoch 38:	########################################	elapsed: 1.15s, reconstruction error: 8.32
# Epoch 39:	########################################	elapsed: 1.16s, reconstruction error: 8.14
# Epoch 40:	########################################	elapsed: 1.15s, reconstruction error: 8.20
# Epoch 41:	########################################	elapsed: 1.15s, reconstruction error: 8.24
# Epoch 42:	########################################	elapsed: 1.13s, reconstruction error: 8.08
# Epoch 43:	########################################	elapsed: 1.14s, reconstruction error: 8.16
# Epoch 44:	########################################	elapsed: 1.15s, reconstruction error: 8.08
# Epoch 45:	########################################	elapsed: 1.13s, reconstruction error: 8.12
# Epoch 46:	########################################	elapsed: 1.14s, reconstruction error: 8.09
# Epoch 47:	########################################	elapsed: 1.13s, reconstruction error: 7.99
# Epoch 48:	########################################	elapsed: 1.17s, reconstruction error: 8.00
# Epoch 49:	########################################	elapsed: 1.14s, reconstruction error: 7.92
# Epoch 50:	########################################	elapsed: 1.16s, reconstruction error: 7.86
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.89s, reconstruction error: 25.80
# Epoch 2:	########################################	elapsed: 0.86s, reconstruction error: 22.98
# Epoch 3:	########################################	elapsed: 0.85s, reconstruction error: 19.73
# Epoch 4:	########################################	elapsed: 0.86s, reconstruction error: 19.64
# Epoch 5:	########################################	elapsed: 0.86s, reconstruction error: 18.73
# Epoch 6:	########################################	elapsed: 0.87s, reconstruction error: 16.91
# Epoch 7:	########################################	elapsed: 0.86s, reconstruction error: 16.55
# Epoch 8:	########################################	elapsed: 0.92s, reconstruction error: 14.99
# Epoch 9:	########################################	elapsed: 0.87s, reconstruction error: 14.98
# Epoch 10:	########################################	elapsed: 0.88s, reconstruction error: 16.81
# Epoch 11:	########################################	elapsed: 0.85s, reconstruction error: 15.36
# Epoch 12:	########################################	elapsed: 0.88s, reconstruction error: 13.67
# Epoch 13:	########################################	elapsed: 0.87s, reconstruction error: 14.31
# Epoch 14:	########################################	elapsed: 0.86s, reconstruction error: 15.08
# Epoch 15:	########################################	elapsed: 0.87s, reconstruction error: 14.76
# Epoch 16:	########################################	elapsed: 0.88s, reconstruction error: 14.06
# Epoch 17:	########################################	elapsed: 0.88s, reconstruction error: 13.03
# Epoch 18:	########################################	elapsed: 0.87s, reconstruction error: 14.43
# Epoch 19:	########################################	elapsed: 0.85s, reconstruction error: 14.27
# Epoch 20:	########################################	elapsed: 0.90s, reconstruction error: 13.12
# Epoch 21:	########################################	elapsed: 0.88s, reconstruction error: 13.27
# Epoch 22:	########################################	elapsed: 0.87s, reconstruction error: 12.65
# Epoch 23:	########################################	elapsed: 0.88s, reconstruction error: 13.33
# Epoch 24:	########################################	elapsed: 0.87s, reconstruction error: 13.13
# Epoch 25:	########################################	elapsed: 0.88s, reconstruction error: 12.73
# Epoch 26:	########################################	elapsed: 0.87s, reconstruction error: 13.82
# Epoch 27:	########################################	elapsed: 0.85s, reconstruction error: 12.26
# Epoch 28:	########################################	elapsed: 0.85s, reconstruction error: 13.37
# Epoch 29:	########################################	elapsed: 0.88s, reconstruction error: 13.63
# Epoch 30:	########################################	elapsed: 0.89s, reconstruction error: 12.50
# Epoch 31:	########################################	elapsed: 0.88s, reconstruction error: 12.69
# Epoch 32:	########################################	elapsed: 0.90s, reconstruction error: 13.00
# Epoch 33:	########################################	elapsed: 0.88s, reconstruction error: 13.12
# Epoch 34:	########################################	elapsed: 0.87s, reconstruction error: 12.68
# Epoch 35:	########################################	elapsed: 0.86s, reconstruction error: 12.55
# Epoch 36:	########################################	elapsed: 0.90s, reconstruction error: 12.77
# Epoch 37:	########################################	elapsed: 0.86s, reconstruction error: 13.07
# Epoch 38:	########################################	elapsed: 0.86s, reconstruction error: 12.91
# Epoch 39:	########################################	elapsed: 0.87s, reconstruction error: 12.30
# Epoch 40:	########################################	elapsed: 0.87s, reconstruction error: 12.26
# Epoch 41:	########################################	elapsed: 0.88s, reconstruction error: 12.51
# Epoch 42:	########################################	elapsed: 0.86s, reconstruction error: 12.85
# Epoch 43:	########################################	elapsed: 0.90s, reconstruction error: 12.24
# Epoch 37:	########################################	elapsed: 1.46s, accuracy: 96.51
# Epoch 38:	########################################	elapsed: 1.44s, accuracy: 96.58
# Epoch 39:	########################################	elapsed: 1.48s, accuracy: 96.58
# Epoch 40:	########################################	elapsed: 1.47s, accuracy: 96.57
# Epoch 41:	########################################	elapsed: 1.44s, accuracy: 96.56
# Epoch 42:	########################################	elapsed: 1.45s, accuracy: 96.54
# Epoch 43:	########################################	elapsed: 1.42s, accuracy: 96.54
# Epoch 44:	########################################	elapsed: 1.42s, accuracy: 96.56
# Epoch 45:	########################################	elapsed: 1.49s, accuracy: 96.56
# Epoch 46:	########################################	elapsed: 1.42s, accuracy: 96.57
# Epoch 47:	########################################	elapsed: 1.47s, accuracy: 96.58
# Epoch 48:	########################################	elapsed: 1.43s, accuracy: 96.59
# Epoch 49:	########################################	elapsed: 1.45s, accuracy: 96.60
# Epoch 50:	########################################	elapsed: 1.45s, accuracy: 96.61
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.77
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.20s, reconstruction error: 75.29
# Epoch 2:	########################################	elapsed: 1.13s, reconstruction error: 55.38
# Epoch 3:	########################################	elapsed: 1.09s, reconstruction error: 42.76
# Epoch 4:	########################################	elapsed: 1.10s, reconstruction error: 36.33
# Epoch 5:	########################################	elapsed: 1.09s, reconstruction error: 32.57
# Epoch 6:	########################################	elapsed: 1.10s, reconstruction error: 24.63
# Epoch 7:	########################################	elapsed: 1.09s, reconstruction error: 20.91
# Epoch 8:	########################################	elapsed: 1.09s, reconstruction error: 18.62
# Epoch 9:	########################################	elapsed: 1.11s, reconstruction error: 17.04
# Epoch 10:	########################################	elapsed: 1.15s, reconstruction error: 15.69
# Epoch 11:	########################################	elapsed: 1.11s, reconstruction error: 14.70
# Epoch 12:	########################################	elapsed: 1.12s, reconstruction error: 13.93
# Epoch 13:	########################################	elapsed: 1.10s, reconstruction error: 13.17
# Epoch 14:	########################################	elapsed: 1.09s, reconstruction error: 12.57
# Epoch 15:	########################################	elapsed: 1.12s, reconstruction error: 11.98
# Epoch 16:	########################################	elapsed: 1.11s, reconstruction error: 11.61
# Epoch 17:	########################################	elapsed: 1.12s, reconstruction error: 11.20
# Epoch 18:	########################################	elapsed: 1.12s, reconstruction error: 10.80
# Epoch 19:	########################################	elapsed: 1.16s, reconstruction error: 10.49
# Epoch 20:	########################################	elapsed: 1.14s, reconstruction error: 10.29
# Epoch 21:	########################################	elapsed: 1.11s, reconstruction error: 10.04
# Epoch 22:	########################################	elapsed: 1.13s, reconstruction error: 9.82
# Epoch 23:	########################################	elapsed: 1.16s, reconstruction error: 9.61
# Epoch 24:	########################################	elapsed: 1.15s, reconstruction error: 9.52
# Epoch 25:	########################################	elapsed: 1.14s, reconstruction error: 9.42
# Epoch 26:	########################################	elapsed: 1.13s, reconstruction error: 9.21
# Epoch 27:	########################################	elapsed: 1.15s, reconstruction error: 9.08
# Epoch 28:	########################################	elapsed: 1.16s, reconstruction error: 8.99
# Epoch 29:	########################################	elapsed: 1.13s, reconstruction error: 8.88
# Epoch 30:	########################################	elapsed: 1.15s, reconstruction error: 8.95
# Epoch 31:	########################################	elapsed: 1.15s, reconstruction error: 8.85
# Epoch 32:	########################################	elapsed: 1.17s, reconstruction error: 8.67
# Epoch 33:	########################################	elapsed: 1.15s, reconstruction error: 8.63
# Epoch 34:	########################################	elapsed: 1.17s, reconstruction error: 8.61
# Epoch 35:	########################################	elapsed: 1.16s, reconstruction error: 8.54
# Epoch 36:	########################################	elapsed: 1.17s, reconstruction error: 8.54
# Epoch 37:	########################################	elapsed: 1.17s, reconstruction error: 8.43
# Epoch 38:	########################################	elapsed: 1.16s, reconstruction error: 8.41
# Epoch 39:	########################################	elapsed: 1.14s, reconstruction error: 8.35
# Epoch 40:	########################################	elapsed: 1.13s, reconstruction error: 8.26
# Epoch 41:	########################################	elapsed: 1.14s, reconstruction error: 8.28
# Epoch 42:	########################################	elapsed: 1.15s, reconstruction error: 8.25
# Epoch 43:	########################################	elapsed: 1.15s, reconstruction error: 8.29
# Epoch 44:	########################################	elapsed: 1.15s, reconstruction error: 8.19
# Epoch 45:	########################################	elapsed: 1.14s, reconstruction error: 8.12
# Epoch 46:	########################################	elapsed: 1.15s, reconstruction error: 8.13
# Epoch 47:	########################################	elapsed: 1.16s, reconstruction error: 8.07
# Epoch 48:	########################################	elapsed: 1.13s, reconstruction error: 8.07
# Epoch 49:	########################################	elapsed: 1.15s, reconstruction error: 8.05
# Epoch 50:	########################################	elapsed: 1.15s, reconstruction error: 8.03
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.86s, reconstruction error: 23.27
# Epoch 2:	########################################	elapsed: 0.87s, reconstruction error: 22.47
# Epoch 3:	########################################	elapsed: 0.85s, reconstruction error: 20.50
# Epoch 4:	########################################	elapsed: 0.83s, reconstruction error: 18.63
# Epoch 5:	########################################	elapsed: 0.86s, reconstruction error: 19.71
# Epoch 6:	########################################	elapsed: 0.85s, reconstruction error: 17.32
# Epoch 7:	########################################	elapsed: 0.87s, reconstruction error: 18.12
# Epoch 8:	########################################	elapsed: 0.88s, reconstruction error: 16.98
# Epoch 9:	########################################	elapsed: 0.86s, reconstruction error: 14.78
# Epoch 10:	########################################	elapsed: 0.87s, reconstruction error: 16.15
# Epoch 11:	########################################	elapsed: 0.85s, reconstruction error: 14.18
# Epoch 12:	########################################	elapsed: 0.86s, reconstruction error: 15.40
# Epoch 13:	########################################	elapsed: 0.86s, reconstruction error: 15.25
# Epoch 14:	########################################	elapsed: 0.87s, reconstruction error: 13.94
# Epoch 15:	########################################	elapsed: 0.87s, reconstruction error: 15.82
# Epoch 16:	########################################	elapsed: 0.89s, reconstruction error: 14.40
# Epoch 17:	########################################	elapsed: 0.86s, reconstruction error: 13.13
# Epoch 18:	########################################	elapsed: 0.90s, reconstruction error: 14.41
# Epoch 19:	########################################	elapsed: 0.85s, reconstruction error: 13.49
# Epoch 20:	########################################	elapsed: 0.87s, reconstruction error: 14.17
# Epoch 21:	########################################	elapsed: 0.87s, reconstruction error: 13.87
# Epoch 22:	########################################	elapsed: 0.87s, reconstruction error: 14.01
# Epoch 23:	########################################	elapsed: 0.86s, reconstruction error: 13.69
# Epoch 24:	########################################	elapsed: 0.86s, reconstruction error: 13.88
# Epoch 25:	########################################	elapsed: 0.85s, reconstruction error: 14.13
# Epoch 26:	########################################	elapsed: 0.87s, reconstruction error: 12.86
# Epoch 27:	########################################	elapsed: 0.84s, reconstruction error: 13.19
# Epoch 28:	########################################	elapsed: 0.86s, reconstruction error: 13.82
# Epoch 29:	########################################	elapsed: 0.88s, reconstruction error: 12.95
# Epoch 30:	########################################	elapsed: 0.89s, reconstruction error: 13.14
# Epoch 31:	########################################	elapsed: 0.86s, reconstruction error: 12.73
# Epoch 32:	########################################	elapsed: 0.87s, reconstruction error: 13.23
# Epoch 33:	########################################	elapsed: 0.88s, reconstruction error: 13.22
# Epoch 34:	########################################	elapsed: 0.85s, reconstruction error: 13.17
# Epoch 35:	########################################	elapsed: 0.87s, reconstruction error: 13.36
# Epoch 36:	########################################	elapsed: 0.85s, reconstruction error: 13.41
# Epoch 37:	########################################	elapsed: 0.87s, reconstruction error: 12.54
# Epoch 38:	########################################	elapsed: 0.85s, reconstruction error: 13.06
# Epoch 39:	########################################	elapsed: 0.88s, reconstruction error: 12.89
# Epoch 40:	########################################	elapsed: 0.86s, reconstruction error: 13.11
# Epoch 41:	########################################	elapsed: 0.89s, reconstruction error: 12.76
# Epoch 42:	########################################	elapsed: 0.87s, reconstruction error: 12.91
# Epoch 43:	########################################	elapsed: 0.88s, reconstruction error: 13.17
# Epoch 44:	########################################	elapsed: 0.86s, reconstruction error: 12.63
# Epoch 45:	########################################	elapsed: 0.85s, reconstruction error: 13.49
# Epoch 46:	########################################	elapsed: 0.87s, reconstruction error: 13.42
# Epoch 47:	########################################	elapsed: 0.86s, reconstruction error: 12.99
# Epoch 48:	########################################	elapsed: 0.88s, reconstruction error: 12.94
# Epoch 49:	########################################	elapsed: 0.83s, reconstruction error: 12.92
# Epoch 50:	########################################	elapsed: 0.86s, reconstruction error: 12.91
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 1.39s, reconstruction error: 14.79
# Epoch 2:	########################################	elapsed: 1.39s, reconstruction error: 14.60
# Epoch 3:	########################################	elapsed: 1.37s, reconstruction error: 14.40
# Epoch 4:	########################################	elapsed: 1.38s, reconstruction error: 13.50
# Epoch 5:	########################################	elapsed: 1.38s, reconstruction error: 13.85
# Epoch 6:	########################################	elapsed: 1.38s, reconstruction error: 14.37
# Epoch 7:	########################################	elapsed: 1.36s, reconstruction error: 14.78
# Epoch 8:	########################################	elapsed: 1.36s, reconstruction error: 14.43
# Epoch 9:	########################################	elapsed: 1.39s, reconstruction error: 12.87
# Epoch 10:	########################################	elapsed: 1.39s, reconstruction error: 14.21
# Epoch 11:	########################################	elapsed: 1.38s, reconstruction error: 13.91
# Epoch 12:	########################################	elapsed: 1.39s, reconstruction error: 13.54
# Epoch 13:	########################################	elapsed: 1.36s, reconstruction error: 12.89
# Epoch 14:	########################################	elapsed: 1.38s, reconstruction error: 12.35
# Epoch 15:	########################################	elapsed: 1.36s, reconstruction error: 13.55
# Epoch 16:	########################################	elapsed: 1.36s, reconstruction error: 14.11
# Epoch 17:	########################################	elapsed: 1.43s, reconstruction error: 12.67
# Epoch 18:	########################################	elapsed: 1.36s, reconstruction error: 13.81
# Epoch 19:	########################################	elapsed: 1.38s, reconstruction error: 13.15
# Epoch 20:	########################################	elapsed: 1.36s, reconstruction error: 13.92
# Epoch 21:	########################################	elapsed: 1.36s, reconstruction error: 12.36
# Epoch 22:	########################################	elapsed: 1.38s, reconstruction error: 12.65
# Epoch 23:	########################################	elapsed: 1.37s, reconstruction error: 12.67
# Epoch 24:	########################################	elapsed: 1.39s, reconstruction error: 13.35
# Epoch 25:	########################################	elapsed: 1.36s, reconstruction error: 12.89
# Epoch 26:	########################################	elapsed: 1.38s, reconstruction error: 13.11
# Epoch 27:	########################################	elapsed: 1.38s, reconstruction error: 12.64
# Epoch 28:	########################################	elapsed: 1.36s, reconstruction error: 13.12
# Epoch 29:	########################################	elapsed: 1.34s, reconstruction error: 12.48
# Epoch 30:	########################################	elapsed: 1.37s, reconstruction error: 12.58
# Epoch 31:	########################################	elapsed: 1.40s, reconstruction error: 12.75
# Epoch 32:	########################################	elapsed: 1.39s, reconstruction error: 12.46
# Epoch 33:	########################################	elapsed: 1.39s, reconstruction error: 12.76
# Epoch 34:	########################################	elapsed: 1.36s, reconstruction error: 12.84
# Epoch 35:	########################################	elapsed: 1.37s, reconstruction error: 12.56
# Epoch 36:	########################################	elapsed: 1.40s, reconstruction error: 12.32
# Epoch 37:	########################################	elapsed: 1.38s, reconstruction error: 12.67
# Epoch 38:	########################################	elapsed: 1.36s, reconstruction error: 12.90
# Epoch 39:	########################################	elapsed: 1.40s, reconstruction error: 12.25
# Epoch 40:	########################################	elapsed: 1.38s, reconstruction error: 12.23
# Epoch 41:	########################################	elapsed: 1.39s, reconstruction error: 12.25
# Epoch 42:	########################################	elapsed: 1.37s, reconstruction error: 13.02
# Epoch 43:	########################################	elapsed: 1.38s, reconstruction error: 11.98
# Epoch 44:	########################################	elapsed: 1.38s, reconstruction error: 12.32
# Epoch 45:	########################################	elapsed: 1.41s, reconstruction error: 12.29
# Epoch 46:	########################################	elapsed: 1.43s, reconstruction error: 12.23
# Epoch 47:	########################################	elapsed: 1.37s, reconstruction error: 12.37
# Epoch 48:	########################################	elapsed: 1.38s, reconstruction error: 12.26
# Epoch 49:	########################################	elapsed: 1.39s, reconstruction error: 12.27
# Epoch 50:	########################################	elapsed: 1.38s, reconstruction error: 12.04
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: