# %%
# !git clone https://github.com/antipainK/AGH_Neural_Networks_and_Deep_Learning
# Out:
# Cloning into 'AGH_Neural_Networks_and_Deep_Learning'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 74 (delta 22), reused 68 (delta 22), pack-reused 0
# Unpacking objects: 100% (74/74), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
#import mkl

#mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def sigmoid(batch, stochastic=False):
    return  1.0 / (1.0 + np.exp(-batch))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

# %% [markdown]
# # Word2Vec

# %%
import pickle
import gzip

with gzip.open("AGH_Neural_Networks_and_Deep_Learning/lab13/text8.dat.gz", "rb") as f:
    train_dict, train_set, train_tokens = pickle.load(f)

train_set = np.random.permutation(train_set)

# %%
from collections import namedtuple
Config = namedtuple("Config", ["dict_size", "vect_size", "neg_samples", "updates", "learning_rate", 
                               "learning_rate_decay", "decay_period", "log_period"])
conf = Config(
    dict_size=len(train_dict),
    vect_size=100,
    neg_samples=10,
    updates=5000000,
    learning_rate=0.1,
    learning_rate_decay=0.995,
    decay_period=10000,
    log_period=10000)

# %% [markdown]
# ## Negative Sampling
#
# In order to train distributed word representations, first:
#  - calculate gradient of the cost function with respect to the `word_vector` and store in `word_grad`.
#  - calculate gradient of the cost function with respect to the `context_vect` and store in `context_grad`.
#  - calculate gradient of the cost function with respect to the sampled `negative_vects` and store in `neg_context_grad`.

# %%
def neg_sample(conf, train_set, train_tokens):
    Vp = randn(conf.dict_size, conf.vect_size)
    Vo = randn(conf.dict_size, conf.vect_size)

    J = 0.0
    learning_rate = conf.learning_rate
    for i in range(conf.updates):
        idx = i % len(train_set)

        word    = train_set[idx, 0]
        context = train_set[idx, 1]
        
        neg_context = np.random.randint(0, len(train_tokens), conf.neg_samples)
        neg_context = train_tokens[neg_context]

        word_vect = Vp[word, :]              # word vector
        context_vect = Vo[context, :];       # context wector
        negative_vects = Vo[neg_context, :]  # sampled negative vectors

        # Cost and gradient calculation starts here
        score_pos = word_vect @ context_vect.T
        score_neg = word_vect @ negative_vects.T

        J -= np.log(sigmoid(score_pos)) + np.sum(np.log(sigmoid(-score_neg)))
        if (i + 1) % conf.log_period == 0:
            print('Update {0}\tcost: {1:>2.2f}'.format(i + 1, J / conf.log_period))
            final_cost = J / conf.log_period
            J = 0.0

        pos_g = 1.0 - sigmoid(score_pos)
        neg_g = sigmoid(score_neg) # Modified

        # Note: use pos_g and neg_g will simplify gradient calculation.
        # Hint: Calculate derivatives for the cost function uwith respect to `word_vector`, 'context_vect` and `negative_vects`.

        word_grad = -pos_g * context_vect + np.sum(as_matrix(neg_g) * negative_vects, axis=0) # Modified
        context_grad = -pos_g * word_vect # Modified
        neg_context_grad = as_matrix(neg_g) @ as_matrix(word_vect).T # Modified

        Vp[word, :] -= learning_rate * word_grad
        Vo[context, :] -= learning_rate * context_grad
        Vo[neg_context, :] -= learning_rate * neg_context_grad

        if i % conf.decay_period == 0:
            learning_rate = learning_rate * conf.learning_rate_decay

    return Vp, Vo, J # Modified

# %%
Vp, Vo, J = neg_sample(conf, train_set, train_tokens)
# Out:
# Update 10000	cost: 36.18
# Update 20000	cost: 28.30
# Update 30000	cost: 23.38
# Update 40000	cost: 19.58
# Update 50000	cost: 17.13
# Update 60000	cost: 15.47
# Update 70000	cost: 13.91
# Update 80000	cost: 12.76
# Update 90000	cost: 12.23
# Update 100000	cost: 11.55
# Update 110000	cost: 10.92
# Update 120000	cost: 10.45
# Update 130000	cost: 10.14
# Update 140000	cost: 9.68
# Update 150000	cost: 9.29
# Update 160000	cost: 9.03
# Update 170000	cost: 8.80
# Update 180000	cost: 8.48
# Update 190000	cost: 8.33
# Update 200000	cost: 8.23
# Update 210000	cost: 8.06
# Update 220000	cost: 7.92
# Update 230000	cost: 7.71
# Update 240000	cost: 7.62
# Update 250000	cost: 7.39
# Update 260000	cost: 7.38
# Update 270000	cost: 7.25
# Update 280000	cost: 7.12
# Update 290000	cost: 6.97
# Update 300000	cost: 6.89
# Update 310000	cost: 6.92
# Update 320000	cost: 6.76
# Update 330000	cost: 6.67
# Update 340000	cost: 6.59
# Update 350000	cost: 6.55
# Update 360000	cost: 6.41
# Update 370000	cost: 6.44
# Update 380000	cost: 6.35
# Update 390000	cost: 6.35
# Update 400000	cost: 6.19
# Update 410000	cost: 6.16
# Update 420000	cost: 6.09
# Update 430000	cost: 6.02
# Update 440000	cost: 6.05
# Update 450000	cost: 5.94
# Update 460000	cost: 5.94
# Update 470000	cost: 5.81
# Update 480000	cost: 5.86
# Update 490000	cost: 5.76
# Update 500000	cost: 5.66
# Update 510000	cost: 5.70
# Update 520000	cost: 5.69
# Update 530000	cost: 5.56
# Update 540000	cost: 5.56
# Update 550000	cost: 5.51
# Update 560000	cost: 5.55
# Update 570000	cost: 5.46
# Update 580000	cost: 5.45
# Update 590000	cost: 5.41
# Update 600000	cost: 5.45
# Update 610000	cost: 5.34
# Update 620000	cost: 5.31
# Update 630000	cost: 5.30
# Update 640000	cost: 5.27
# Update 650000	cost: 5.32
# Update 660000	cost: 5.23
# Update 670000	cost: 5.20
# Update 680000	cost: 5.17
# Update 690000	cost: 5.20
# Update 700000	cost: 5.21
# Update 710000	cost: 5.13
# Update 720000	cost: 5.12
# Update 730000	cost: 5.07
# Update 740000	cost: 5.08
# Update 750000	cost: 5.05
# Update 760000	cost: 5.05
# Update 770000	cost: 4.98
# Update 780000	cost: 4.98
# Update 790000	cost: 4.93
# Update 800000	cost: 4.94
# Update 810000	cost: 4.92
# Update 820000	cost: 4.87
# Update 830000	cost: 4.89
# Update 840000	cost: 4.85
# Update 850000	cost: 4.87
# Update 860000	cost: 4.80
# Update 870000	cost: 4.78
# Update 880000	cost: 4.77
# Update 890000	cost: 4.78
# Update 900000	cost: 4.72
# Update 910000	cost: 4.69
# Update 920000	cost: 4.73
# Update 930000	cost: 4.71
# Update 940000	cost: 4.70
# Update 950000	cost: 4.70
# Update 960000	cost: 4.69
# Update 970000	cost: 4.64
# Update 980000	cost: 4.59
# Update 990000	cost: 4.64
# Update 1000000	cost: 4.62
# Update 1010000	cost: 4.58
# Update 1020000	cost: 4.60
# Update 1030000	cost: 4.59
# Update 1040000	cost: 4.58
# Update 1050000	cost: 4.53
# Update 1060000	cost: 4.53
# Update 1070000	cost: 4.59
# Update 1080000	cost: 4.54
# Update 1090000	cost: 4.54
# Update 1100000	cost: 4.48
# Update 1110000	cost: 4.53
# Update 1120000	cost: 4.46
# Update 1130000	cost: 4.46
# Update 1140000	cost: 4.45
# Update 1150000	cost: 4.49
# Update 1160000	cost: 4.43
# Update 1170000	cost: 4.42
# Update 1180000	cost: 4.36
# Update 1190000	cost: 4.42
# Update 1200000	cost: 4.39
# Update 1210000	cost: 4.36
# Update 1220000	cost: 4.40
# Update 1230000	cost: 4.40
# Update 1240000	cost: 4.38
# Update 1250000	cost: 4.33
# Update 1260000	cost: 4.34
# Update 1270000	cost: 4.35
# Update 1280000	cost: 4.38
# Update 1290000	cost: 4.25
# Update 1300000	cost: 4.30
# Update 1310000	cost: 4.26
# Update 1320000	cost: 4.32
# Update 1330000	cost: 4.31
# Update 1340000	cost: 4.25
# Update 1350000	cost: 4.27
# Update 1360000	cost: 4.24
# Update 1370000	cost: 4.20
# Update 1380000	cost: 4.23
# Update 1390000	cost: 4.21
# Update 1400000	cost: 4.18
# Update 1410000	cost: 4.21
# Update 1420000	cost: 4.21
# Update 1430000	cost: 4.19
# Update 1440000	cost: 4.23
# Update 1450000	cost: 4.17
# Update 1460000	cost: 4.25
# Update 1470000	cost: 4.17
# Update 1480000	cost: 4.19
# Update 1490000	cost: 4.13
# Update 1500000	cost: 4.11
# Update 1510000	cost: 4.12
# Update 1520000	cost: 4.15
# Update 1530000	cost: 4.12
# Update 1540000	cost: 4.14
# Update 1550000	cost: 4.13
# Update 1560000	cost: 4.11
# Update 1570000	cost: 4.13
# Update 1580000	cost: 4.06
# Update 1590000	cost: 4.13
# Update 1600000	cost: 4.13
# Update 1610000	cost: 4.08
# Update 1620000	cost: 4.06
# Update 1630000	cost: 4.15
# Update 1640000	cost: 4.07
# Update 1650000	cost: 4.02
# Update 1660000	cost: 4.05
# Update 1670000	cost: 4.05
# Update 1680000	cost: 4.04
# Update 1690000	cost: 4.04
# Update 1700000	cost: 4.02
# Update 1710000	cost: 4.04
# Update 1720000	cost: 4.05
# Update 1730000	cost: 3.98
# Update 1740000	cost: 4.01
# Update 1750000	cost: 3.99
# Update 1760000	cost: 4.00
# Update 1770000	cost: 4.00
# Update 1780000	cost: 3.96
# Update 1790000	cost: 4.03
# Update 1800000	cost: 3.98
# Update 1810000	cost: 4.00
# Update 1820000	cost: 3.96
# Update 1830000	cost: 3.96
# Update 1840000	cost: 3.95
# Update 1850000	cost: 4.02
# Update 1860000	cost: 3.95
# Update 1870000	cost: 3.97
# Update 1880000	cost: 3.98
# Update 1890000	cost: 4.02
# Update 1900000	cost: 3.90
# Update 1910000	cost: 3.95
# Update 1920000	cost: 3.93
# Update 1930000	cost: 3.91
# Update 1940000	cost: 3.93
# Update 1950000	cost: 3.94
# Update 1960000	cost: 3.91
# Update 1970000	cost: 3.94
# Update 1980000	cost: 3.92
# Update 1990000	cost: 3.89
# Update 2000000	cost: 3.92
# Update 2010000	cost: 3.87
# Update 2020000	cost: 3.86
# Update 2030000	cost: 3.87
# Update 2040000	cost: 3.88
# Update 2050000	cost: 3.90
# Update 2060000	cost: 3.87
# Update 2070000	cost: 3.88
# Update 2080000	cost: 3.83
# Update 2090000	cost: 3.88
# Update 2100000	cost: 3.84
# Update 2110000	cost: 3.90
# Update 2120000	cost: 3.85
# Update 2130000	cost: 3.85
# Update 2140000	cost: 3.83
# Update 2150000	cost: 3.85
# Update 2160000	cost: 3.89
# Update 2170000	cost: 3.82
# Update 2180000	cost: 3.82
# Update 2190000	cost: 3.80
# Update 2200000	cost: 3.85
# Update 2210000	cost: 3.81
# Update 2220000	cost: 3.85
# Update 2230000	cost: 3.82
# Update 2240000	cost: 3.86
# Update 2250000	cost: 3.78
# Update 2260000	cost: 3.83
# Update 2270000	cost: 3.82
# Update 2280000	cost: 3.78
# Update 2290000	cost: 3.78
# Update 2300000	cost: 3.78
# Update 2310000	cost: 3.75
# Update 2320000	cost: 3.81
# Update 2330000	cost: 3.79
# Update 2340000	cost: 3.76
# Update 2350000	cost: 3.81
# Update 2360000	cost: 3.80
# Update 2370000	cost: 3.75
# Update 2380000	cost: 3.77
# Update 2390000	cost: 3.79
# Update 2400000	cost: 3.76
# Update 2410000	cost: 3.80
# Update 2420000	cost: 3.76
# Update 2430000	cost: 3.75
# Update 2440000	cost: 3.75
# Update 2450000	cost: 3.78
# Update 2460000	cost: 3.77
# Update 2470000	cost: 3.77
# Update 2480000	cost: 3.73
# Update 2490000	cost: 3.76
# Update 2500000	cost: 3.72
# Update 2510000	cost: 3.76
# Update 2520000	cost: 3.74
# Update 2530000	cost: 3.73
# Update 2540000	cost: 3.75
# Update 2550000	cost: 3.72
# Update 2560000	cost: 3.71
# Update 2570000	cost: 3.72
# Update 2580000	cost: 3.71
# Update 2590000	cost: 3.72
# Update 2600000	cost: 3.69
# Update 2610000	cost: 3.72
# Update 2620000	cost: 3.73
# Update 2630000	cost: 3.70
# Update 2640000	cost: 3.75
# Update 2650000	cost: 3.70
# Update 2660000	cost: 3.76
# Update 2670000	cost: 3.70
# Update 2680000	cost: 3.72
# Update 2690000	cost: 3.67
# Update 2700000	cost: 3.67
# Update 2710000	cost: 3.71
# Update 2720000	cost: 3.67
# Update 2730000	cost: 3.70
# Update 2740000	cost: 3.70
# Update 2750000	cost: 3.68
# Update 2760000	cost: 3.71
# Update 2770000	cost: 3.69
# Update 2780000	cost: 3.66
# Update 2790000	cost: 3.68
# Update 2800000	cost: 3.72
# Update 2810000	cost: 3.69
# Update 2820000	cost: 3.68
# Update 2830000	cost: 3.65
# Update 2840000	cost: 3.68
# Update 2850000	cost: 3.67
# Update 2860000	cost: 3.66
# Update 2870000	cost: 3.69
# Update 2880000	cost: 3.66
# Update 2890000	cost: 3.67
# Update 2900000	cost: 3.67
# Update 2910000	cost: 3.65
# Update 2920000	cost: 3.65
# Update 2930000	cost: 3.67
# Update 2940000	cost: 3.63
# Update 2950000	cost: 3.66
# Update 2960000	cost: 3.65
# Update 2970000	cost: 3.64
# Update 2980000	cost: 3.66
# Update 2990000	cost: 3.66
# Update 3000000	cost: 3.66
# Update 3010000	cost: 3.63
# Update 3020000	cost: 3.64
# Update 3030000	cost: 3.64
# Update 3040000	cost: 3.66
# Update 3050000	cost: 3.60
# Update 3060000	cost: 3.65
# Update 3070000	cost: 3.63
# Update 3080000	cost: 3.63
# Update 3090000	cost: 3.63
# Update 3100000	cost: 3.62
# Update 3110000	cost: 3.59
# Update 3120000	cost: 3.66
# Update 3130000	cost: 3.61
# Update 3140000	cost: 3.62
# Update 3150000	cost: 3.61
# Update 3160000	cost: 3.65
# Update 3170000	cost: 3.60
# Update 3180000	cost: 3.63
# Update 3190000	cost: 3.60
# Update 3200000	cost: 3.62
# Update 3210000	cost: 3.58
# Update 3220000	cost: 3.59
# Update 3230000	cost: 3.62
# Update 3240000	cost: 3.61
# Update 3250000	cost: 3.62
# Update 3260000	cost: 3.58
# Update 3270000	cost: 3.63
# Update 3280000	cost: 3.62
# Update 3290000	cost: 3.63
# Update 3300000	cost: 3.63
# Update 3310000	cost: 3.59
# Update 3320000	cost: 3.60
# Update 3330000	cost: 3.57
# Update 3340000	cost: 3.57
# Update 3350000	cost: 3.59
# Update 3360000	cost: 3.57
# Update 3370000	cost: 3.58
# Update 3380000	cost: 3.59
# Update 3390000	cost: 3.57
# Update 3400000	cost: 3.56
# Update 3410000	cost: 3.55
# Update 3420000	cost: 3.57
# Update 3430000	cost: 3.57
# Update 3440000	cost: 3.58
# Update 3450000	cost: 3.56
# Update 3460000	cost: 3.57
# Update 3470000	cost: 3.55
# Update 3480000	cost: 3.57
# Update 3490000	cost: 3.57
# Update 3500000	cost: 3.58
# Update 3510000	cost: 3.59
# Update 3520000	cost: 3.57
# Update 3530000	cost: 3.58
# Update 3540000	cost: 3.60
# Update 3550000	cost: 3.59
# Update 3560000	cost: 3.59
# Update 3570000	cost: 3.54
# Update 3580000	cost: 3.58
# Update 3590000	cost: 3.56
# Update 3600000	cost: 3.53
# Update 3610000	cost: 3.58
# Update 3620000	cost: 3.57
# Update 3630000	cost: 3.55
# Update 3640000	cost: 3.55
# Update 3650000	cost: 3.56
# Update 3660000	cost: 3.56
# Update 3670000	cost: 3.53
# Update 3680000	cost: 3.54
# Update 3690000	cost: 3.56
# Update 3700000	cost: 3.51
# Update 3710000	cost: 3.55
# Update 3720000	cost: 3.55
# Update 3730000	cost: 3.55
# Update 3740000	cost: 3.54
# Update 3750000	cost: 3.56
# Update 3760000	cost: 3.55
# Update 3770000	cost: 3.52
# Update 3780000	cost: 3.56
# Update 3790000	cost: 3.54
# Update 3800000	cost: 3.51
# Update 3810000	cost: 3.56
# Update 3820000	cost: 3.54
# Update 3830000	cost: 3.53
# Update 3840000	cost: 3.51
# Update 3850000	cost: 3.49
# Update 3860000	cost: 3.56
# Update 3870000	cost: 3.52
# Update 3880000	cost: 3.54
# Update 3890000	cost: 3.55
# Update 3900000	cost: 3.53
# Update 3910000	cost: 3.55
# Update 3920000	cost: 3.51
# Update 3930000	cost: 3.53
# Update 3940000	cost: 3.51
# Update 3950000	cost: 3.51
# Update 3960000	cost: 3.53
# Update 3970000	cost: 3.52
# Update 3980000	cost: 3.52
# Update 3990000	cost: 3.53
# Update 4000000	cost: 3.53
# Update 4010000	cost: 3.52
# Update 4020000	cost: 3.51
# Update 4030000	cost: 3.51
# Update 4040000	cost: 3.57
# Update 4050000	cost: 3.48
# Update 4060000	cost: 3.51
# Update 4070000	cost: 3.51
# Update 4080000	cost: 3.54
# Update 4090000	cost: 3.53
# Update 4100000	cost: 3.53
# Update 4110000	cost: 3.51
# Update 4120000	cost: 3.50
# Update 4130000	cost: 3.51
# Update 4140000	cost: 3.50
# Update 4150000	cost: 3.52
# Update 4160000	cost: 3.49
# Update 4170000	cost: 3.52
# Update 4180000	cost: 3.51
# Update 4190000	cost: 3.51
# Update 4200000	cost: 3.52
# Update 4210000	cost: 3.48
# Update 4220000	cost: 3.52
# Update 4230000	cost: 3.49
# Update 4240000	cost: 3.51
# Update 4250000	cost: 3.51
# Update 4260000	cost: 3.49
# Update 4270000	cost: 3.52
# Update 4280000	cost: 3.49
# Update 4290000	cost: 3.51
# Update 4300000	cost: 3.50
# Update 4310000	cost: 3.51
# Update 4320000	cost: 3.49
# Update 4330000	cost: 3.49
# Update 4340000	cost: 3.47
# Update 4350000	cost: 3.47
# Update 4360000	cost: 3.49
# Update 4370000	cost: 3.48
# Update 4380000	cost: 3.48
# Update 4390000	cost: 3.47
# Update 4400000	cost: 3.48
# Update 4410000	cost: 3.47
# Update 4420000	cost: 3.49
# Update 4430000	cost: 3.49
# Update 4440000	cost: 3.45
# Update 4450000	cost: 3.47
# Update 4460000	cost: 3.47
# Update 4470000	cost: 3.48
# Update 4480000	cost: 3.47
# Update 4490000	cost: 3.49
# Update 4500000	cost: 3.48
# Update 4510000	cost: 3.48
# Update 4520000	cost: 3.49
# Update 4530000	cost: 3.47
# Update 4540000	cost: 3.46
# Update 4550000	cost: 3.48
# Update 4560000	cost: 3.46
# Update 4570000	cost: 3.47
# Update 4580000	cost: 3.48
# Update 4590000	cost: 3.47
# Update 4600000	cost: 3.46
# Update 4610000	cost: 3.51
# Update 4620000	cost: 3.50
# Update 4630000	cost: 3.45
# Update 4640000	cost: 3.45
# Update 4650000	cost: 3.48
# Update 4660000	cost: 3.47
# Update 4670000	cost: 3.43
# Update 4680000	cost: 3.47
# Update 4690000	cost: 3.47
# Update 4700000	cost: 3.48
# Update 4710000	cost: 3.43
# Update 4720000	cost: 3.47
# Update 4730000	cost: 3.46
# Update 4740000	cost: 3.46
# Update 4750000	cost: 3.47
# Update 4760000	cost: 3.51
# Update 4770000	cost: 3.45
# Update 4780000	cost: 3.46
# Update 4790000	cost: 3.46
# Update 4800000	cost: 3.48
# Update 4810000	cost: 3.46
# Update 4820000	cost: 3.46
# Update 4830000	cost: 3.46
# Update 4840000	cost: 3.46
# Update 4850000	cost: 3.46
# Update 4860000	cost: 3.46
# Update 4870000	cost: 3.47
# Update 4880000	cost: 3.46
# Update 4890000	cost: 3.44
# Update 4900000	cost: 3.49
# Update 4910000	cost: 3.46
# Update 4920000	cost: 3.47
# Update 4930000	cost: 3.47
# Update 4940000	cost: 3.44
# Update 4950000	cost: 3.46
# Update 4960000	cost: 3.43
# Update 4970000	cost: 3.46
# Update 4980000	cost: 3.46
# Update 4990000	cost: 3.45
# Update 5000000	cost: 3.45

# %% [markdown]
# ### Word similarity

# %%
def lookup_word_idx(word, word_dict):
    try:
        return np.argwhere(np.array(word_dict) == word)[0][0]
    except:
        raise Exception("No such word in dict: {}".format(word))

def similar_words(embeddings, word, word_dict, hits):
    word_idx = lookup_word_idx(word, word_dict)
    similarity_scores = embeddings @ embeddings[word_idx]
    similar_word_idxs = np.argsort(-similarity_scores)    
    return [word_dict[i] for i in similar_word_idxs[:hits]]

# %%
print('\n\nTraining cost: {0:>2.2f}\n\n'.format(J))

Vp_norm = Vp / as_matrix(np.linalg.norm(Vp , axis=1))
for w in ['zero', 'computer', 'cars', 'home', 'album']:
    similar = similar_words(Vp_norm, w, train_dict, 5)
    print('Words similar to {}: {}'.format(w, ", ".join(similar)))
# Out:
# Training cost: 0.00
#
#
# Words similar to zero: zero, four, five, three, eight
# Words similar to computer: computer, software, technology, digital, design
# Words similar to cars: cars, line, speed, range, light
# Words similar to home: home, moved, park, city, street
# Words similar to album: album, songs, band, music, released
